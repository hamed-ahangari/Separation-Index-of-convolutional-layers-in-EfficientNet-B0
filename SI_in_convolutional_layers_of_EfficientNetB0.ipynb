# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0

# %% [markdown]
# ## Loading data
# Here we load data from tensorflow_datasets (hereafter TFDS). Stanford Dogs dataset is provided in TFDS as stanford_dogs. It features 20,580 images that belong to 120 classes of dog breeds (12,000 for training and 8,580 for testing).

# %%
# IMG_SIZE is determined by EfficientNet model choice
IMG_SIZE = 224

# %%
import tensorflow_datasets as tfds

batch_size = 64

dataset_name = "stanford_dogs"
(ds_train, ds_test), ds_info = tfds.load(
    dataset_name, split=["train", "test"], with_info=True, as_supervised=True
)
NUM_CLASSES = ds_info.features["label"].num_classes
# Out:
# Downloading and preparing dataset stanford_dogs/0.2.0 (download: 778.12 MiB, generated: Unknown size, total: 778.12 MiB) to /root/tensorflow_datasets/stanford_dogs/0.2.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/stanford_dogs/0.2.0.incomplete62DGA0/stanford_dogs-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=12000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/stanford_dogs/0.2.0.incomplete62DGA0/stanford_dogs-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=8580.0), HTML(value='')))
# Dataset stanford_dogs downloaded and prepared to /root/tensorflow_datasets/stanford_dogs/0.2.0. Subsequent calls will reuse this data.

# %%
size = (IMG_SIZE, IMG_SIZE)
ds_train = ds_train.map(lambda image, label: (tf.image.resize(image, size), label))
ds_test = ds_test.map(lambda image, label: (tf.image.resize(image, size), label))

# %% [markdown]
# ## Visualizing the data
# The following code shows the first 9 images with their labels.

# %%
import matplotlib.pyplot as plt


def format_label(label):
    string_label = label_info.int2str(label)
    return string_label.split("-")[1]


label_info = ds_info.features["label"]
for i, (image, label) in enumerate(ds_train.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.title("{}".format(format_label(label)))
    plt.axis("off")

# %% [markdown]
# ## Prepare inputs
# Once we verify the input data and augmentation are working correctly, we prepare dataset for training. The input data are resized to uniform IMG_SIZE. The labels are put into one-hot (a.k.a. categorical) encoding. The dataset is batched.

# %%
# One-hot / categorical encoding
def input_preprocess(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


ds_train = ds_train.map(
    input_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE
)
ds_train = ds_train.batch(batch_size=batch_size, drop_remainder=True)
ds_train = ds_train.prefetch(tf.data.experimental.AUTOTUNE)

ds_test = ds_test.map(input_preprocess)
ds_test = ds_test.batch(batch_size=batch_size, drop_remainder=True)

# %% [markdown]
# ## Data augmentation
# We can use preprocessing layers APIs for image augmentation.

# %%
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

img_augmentation = Sequential(
    [
        preprocessing.RandomRotation(factor=0.15),
        preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
        preprocessing.RandomFlip(),
        preprocessing.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %% [markdown]
# # Transfer learning from pre-trained weights

# %% [markdown]
# ## Loading the latest EfficientNet weights
# Here we download noisy-student version of EfficientNet B0

# %%
# %%capture

# !wget "https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/noisystudent/noisy_student_efficientnet-b0.tar.gz"
# !tar -xf "noisy_student_efficientnet-b0.tar.gz"


# Then use the script efficientnet_weight_update_util.py to convert ckpt file to h5 file.
# Download the script 
# !wget https://raw.githubusercontent.com/tensorflow/tensorflow/master/tensorflow/python/keras/applications/efficientnet_weight_update_util.py
# Convert the ckpt file of weights to h5 file
# !python efficientnet_weight_update_util.py --model b0 --notop --ckpt "noisy_student_efficientnet-b0/model.ckpt" --o "efficientnetb0_notop.h5"

# %% [markdown]
# ## First Step
# To continue, we initialize the model with pre-trained noisy-student version of B0, and we fine-tune it on our own dataset.

# %%
def build_model(num_classes):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = img_augmentation(inputs)
    model = EfficientNetB0(weights="efficientnetb0_notop.h5", include_top=False, input_tensor=x)

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax", name="last_layer")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="PreTrainedEfficientNetB0")
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
model = build_model(num_classes=NUM_CLASSES)

epochs = 25
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=1)
# Out:
# Epoch 1/25
# 187/187 [==============================] - 50s 151ms/step - loss: 4.1487 - accuracy: 0.3050 - val_loss: 1.0822 - val_accuracy: 0.6969
# Epoch 2/25
# 187/187 [==============================] - 27s 143ms/step - loss: 1.9658 - accuracy: 0.5134 - val_loss: 0.8540 - val_accuracy: 0.7431
# Epoch 3/25
# 187/187 [==============================] - 27s 143ms/step - loss: 1.5900 - accuracy: 0.5689 - val_loss: 0.7665 - val_accuracy: 0.7669
# Epoch 4/25
# 187/187 [==============================] - 27s 142ms/step - loss: 1.4937 - accuracy: 0.5874 - val_loss: 0.7892 - val_accuracy: 0.7643
# Epoch 5/25
# 187/187 [==============================] - 27s 143ms/step - loss: 1.4578 - accuracy: 0.5927 - val_loss: 0.7821 - val_accuracy: 0.7687
# Epoch 6/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.4325 - accuracy: 0.5954 - val_loss: 0.7961 - val_accuracy: 0.7578
# Epoch 7/25
# 187/187 [==============================] - 27s 142ms/step - loss: 1.3821 - accuracy: 0.6099 - val_loss: 0.7992 - val_accuracy: 0.7626
# Epoch 8/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3806 - accuracy: 0.6143 - val_loss: 0.7766 - val_accuracy: 0.7641
# Epoch 9/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3857 - accuracy: 0.6118 - val_loss: 0.7873 - val_accuracy: 0.7677
# Epoch 10/25
# 187/187 [==============================] - 27s 142ms/step - loss: 1.3555 - accuracy: 0.6258 - val_loss: 0.8290 - val_accuracy: 0.7516
# Epoch 11/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3204 - accuracy: 0.6308 - val_loss: 0.8172 - val_accuracy: 0.7594
# Epoch 12/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3611 - accuracy: 0.6224 - val_loss: 0.8318 - val_accuracy: 0.7556
# Epoch 13/25
# 187/187 [==============================] - 26s 140ms/step - loss: 1.3640 - accuracy: 0.6232 - val_loss: 0.8196 - val_accuracy: 0.7620
# Epoch 14/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3383 - accuracy: 0.6231 - val_loss: 0.8330 - val_accuracy: 0.7640
# Epoch 15/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3383 - accuracy: 0.6272 - val_loss: 0.8634 - val_accuracy: 0.7514
# Epoch 16/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3380 - accuracy: 0.6325 - val_loss: 0.8536 - val_accuracy: 0.7590
# Epoch 17/25
# 187/187 [==============================] - 27s 141ms/step - loss: 1.3564 - accuracy: 0.6241 - val_loss: 0.8707 - val_accuracy: 0.7584
# Epoch 18/25
# 187/187 [==============================] - 26s 140ms/step - loss: 1.3827 - accuracy: 0.6153 - val_loss: 0.8443 - val_accuracy: 0.7631
# Epoch 19/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3023 - accuracy: 0.6364 - val_loss: 0.8927 - val_accuracy: 0.7474
# Epoch 20/25
# 187/187 [==============================] - 26s 140ms/step - loss: 1.3476 - accuracy: 0.6272 - val_loss: 0.8416 - val_accuracy: 0.7678
# Epoch 21/25
# 187/187 [==============================] - 26s 141ms/step - loss: 1.3620 - accuracy: 0.6185 - val_loss: 0.8831 - val_accuracy: 0.7505
# Epoch 22/25
# 187/187 [==============================] - 26s 140ms/step - loss: 1.3671 - accuracy: 0.6215 - val_loss: 0.8694 - val_accuracy: 0.7572
# Epoch 23/25
# 187/187 [==============================] - 26s 140ms/step - loss: 1.3425 - accuracy: 0.6329 - val_loss: 0.8949 - val_accuracy: 0.7501
# Epoch 24/25
# 187/187 [==============================] - 26s 140ms/step - loss: 1.3621 - accuracy: 0.6297 - val_loss: 0.8551 - val_accuracy: 0.7618
# Epoch 25/25
# 187/187 [==============================] - 26s 139ms/step - loss: 1.3541 - accuracy: 0.6252 - val_loss: 0.8585 - val_accuracy: 0.7638

# %%
def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()


plot_hist(hist)

# %%
tf.keras.utils.plot_model(model)

# %% [markdown]
# ## Second Step
# The second step is to unfreeze a number of layers, except BatchNormalizations layers, and fit the model using smaller learning rate.

# %%
def unfreeze_model(model):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )


unfreeze_model(model)

epochs = 10
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=1)
plot_hist(hist)
# Out:
# Epoch 1/10
# 187/187 [==============================] - 35s 151ms/step - loss: 1.2236 - accuracy: 0.6538 - val_loss: 0.7159 - val_accuracy: 0.7983
# Epoch 2/10
# 187/187 [==============================] - 27s 144ms/step - loss: 1.0031 - accuracy: 0.7032 - val_loss: 0.7163 - val_accuracy: 0.7973
# Epoch 3/10
# 187/187 [==============================] - 27s 144ms/step - loss: 0.9266 - accuracy: 0.7219 - val_loss: 0.7140 - val_accuracy: 0.7983
# Epoch 4/10
# 187/187 [==============================] - 27s 143ms/step - loss: 0.8930 - accuracy: 0.7298 - val_loss: 0.7184 - val_accuracy: 0.8001
# Epoch 5/10
# 187/187 [==============================] - 27s 145ms/step - loss: 0.8657 - accuracy: 0.7395 - val_loss: 0.7210 - val_accuracy: 0.7986
# Epoch 6/10
# 187/187 [==============================] - 27s 143ms/step - loss: 0.8182 - accuracy: 0.7466 - val_loss: 0.7265 - val_accuracy: 0.7975
# Epoch 7/10
# 187/187 [==============================] - 27s 144ms/step - loss: 0.7873 - accuracy: 0.7527 - val_loss: 0.7244 - val_accuracy: 0.7956
# Epoch 8/10
# 187/187 [==============================] - 27s 144ms/step - loss: 0.7614 - accuracy: 0.7698 - val_loss: 0.7262 - val_accuracy: 0.7977
# Epoch 9/10
# 187/187 [==============================] - 27s 144ms/step - loss: 0.7240 - accuracy: 0.7727 - val_loss: 0.7435 - val_accuracy: 0.7929
# Epoch 10/10
# 187/187 [==============================] - 27s 143ms/step - loss: 0.6943 - accuracy: 0.7819 - val_loss: 0.7329 - val_accuracy: 0.7954

# %%
for layer in model.layers:
    layer.trainable = False

# %%
model.save("fine-tuned_weights_using_StanfordDogs.h5")

# %% [markdown]
# # Calculate Separation Index

# %%
ds_train = ds_train.unbatch()
ds_test = ds_test.unbatch()

encoded_y = tf.one_hot([i for i in range(NUM_CLASSES)], NUM_CLASSES).numpy()

# %%
def calculate_separation_index(predictions, labels):
    Q = len(labels)
    N = NUM_CLASSES
    M = np.zeros([N, np.prod(predictions[0].shape)])
    global encoded_y
    for dog in range(N):
        the_sum = 0.0
        counter = 0.0
        for q in range(Q):
            if (labels[q] == encoded_y[dog]).all():
                the_sum += predictions[q]
                counter += 1

        the_sum /= counter
        the_sum = the_sum.reshape((np.prod(predictions[0].shape), ))
        M[dog, :] = the_sum

    I = 0
    for q in range(Q):
        vect_predictions = predictions[q].reshape((np.prod(predictions[0].shape), ))
        A = np.abs(vect_predictions - M)
        B = np.linalg.norm(A, axis=1)

        if (np.argmin(B) == np.argmax(labels[q])).all():
            I += 1

    return I / Q

# %% [markdown]
# ### Make a sub-dataset containing 10 images of each class

# %%
# Extract 10 images for each class out of train and test set and stack them together
sliced_ds_train = ds_train.filter(lambda x, y: tf.reduce_all(y == encoded_y[0])).take(10)
sliced_ds_test = ds_test.filter(lambda x, y: tf.reduce_all(y == encoded_y[0])).take(10)

for i in range(1, NUM_CLASSES):
    sliced_ds_train = sliced_ds_train.concatenate(ds_train.filter(lambda x, y: tf.reduce_all(y == encoded_y[i])).take(10))
    sliced_ds_test = sliced_ds_test.concatenate(ds_test.filter(lambda x, y: tf.reduce_all(y == encoded_y[i])).take(10))

sliced_ds_train = sliced_ds_train.shuffle(10*NUM_CLASSES).batch(1)
sliced_ds_test = sliced_ds_test.shuffle(10*NUM_CLASSES).batch(1)

# %%
# Extract the labels out from the dataset
import numpy as np

train_set_labels = np.concatenate([y.numpy() for x, y in sliced_ds_train], axis=0)
test_set_labels = np.concatenate([y.numpy() for x, y in sliced_ds_test], axis=0)

# %%
len(train_set_labels)
# Out:
# 1200

# %% [markdown]
# ### SI values on the output of some layers within the convolutional blocks

# %%
SI_on_train_set = []
SI_on_test_set = []
selected_layers = []

for layer in model.layers:
    if layer.name.endswith("conv") or isinstance(layer, layers.Multiply) or isinstance(layer, layers.Add):
        layer_model = tf.keras.Model(model.input, layer.output)

        predictions = layer_model.predict(sliced_ds_train)
        value = calculate_separation_index(predictions, train_set_labels)
        SI_on_train_set.append(value)
        del predictions

        predictions = layer_model.predict(sliced_ds_test)
        value = calculate_separation_index(predictions, test_set_labels)
        SI_on_test_set.append(value)
        del predictions

        del layer_model

        name = f"{layer.__class__.__name__} - {layer.name}"
        selected_layers.append(name)

        print(f"Layer name: {name},  SI on tarin set: {round(SI_on_train_set[-1],3)},  SI on test set: {round(SI_on_test_set[-1],3)}")
# Out:
# Layer name: Conv2D - stem_conv,  SI on tarin set: 0.338,  SI on test set: 0.33
# Layer name: DepthwiseConv2D - block1a_dwconv,  SI on tarin set: 0.739,  SI on test set: 0.73
# Layer name: Multiply - block1a_se_excite,  SI on tarin set: 0.918,  SI on test set: 0.906
# Layer name: Conv2D - block1a_project_conv,  SI on tarin set: 0.772,  SI on test set: 0.768
# Layer name: Conv2D - block2a_expand_conv,  SI on tarin set: 0.99,  SI on test set: 0.986
# Layer name: DepthwiseConv2D - block2a_dwconv,  SI on tarin set: 0.96,  SI on test set: 0.974
# Layer name: Multiply - block2a_se_excite,  SI on tarin set: 0.923,  SI on test set: 0.922
# Layer name: Conv2D - block2a_project_conv,  SI on tarin set: 0.827,  SI on test set: 0.802
# Layer name: Conv2D - block2b_expand_conv,  SI on tarin set: 0.721,  SI on test set: 0.69
# Layer name: DepthwiseConv2D - block2b_dwconv,  SI on tarin set: 0.768,  SI on test set: 0.789
# Layer name: Multiply - block2b_se_excite,  SI on tarin set: 0.993,  SI on test set: 0.998
# Layer name: Conv2D - block2b_project_conv,  SI on tarin set: 0.994,  SI on test set: 0.991
# Layer name: Add - block2b_add,  SI on tarin set: 0.998,  SI on test set: 0.998
# Layer name: Conv2D - block3a_expand_conv,  SI on tarin set: 0.998,  SI on test set: 0.999
# Layer name: DepthwiseConv2D - block3a_dwconv,  SI on tarin set: 0.783,  SI on test set: 0.796
# Layer name: Multiply - block3a_se_excite,  SI on tarin set: 1.0,  SI on test set: 1.0
# Layer name: Conv2D - block3a_project_conv,  SI on tarin set: 0.983,  SI on test set: 0.987
# Layer name: Conv2D - block3b_expand_conv,  SI on tarin set: 0.983,  SI on test set: 0.982
# Layer name: DepthwiseConv2D - block3b_dwconv,  SI on tarin set: 0.925,  SI on test set: 0.926
# Layer name: Multiply - block3b_se_excite,  SI on tarin set: 1.0,  SI on test set: 1.0
# Layer name: Conv2D - block3b_project_conv,  SI on tarin set: 1.0,  SI on test set: 1.0
# Layer name: Add - block3b_add,  SI on tarin set: 1.0,  SI on test set: 1.0
# Layer name: Conv2D - block4a_expand_conv,  SI on tarin set: 0.998,  SI on test set: 0.998
# Layer name: DepthwiseConv2D - block4a_dwconv,  SI on tarin set: 0.958,  SI on test set: 0.955
# Layer name: Multiply - block4a_se_excite,  SI on tarin set: 0.994,  SI on test set: 0.995
# Layer name: Conv2D - block4a_project_conv,  SI on tarin set: 0.961,  SI on test set: 0.968
# Layer name: Conv2D - block4b_expand_conv,  SI on tarin set: 0.963,  SI on test set: 0.967
# Layer name: DepthwiseConv2D - block4b_dwconv,  SI on tarin set: 0.972,  SI on test set: 0.978
# Layer name: Multiply - block4b_se_excite,  SI on tarin set: 1.0,  SI on test set: 1.0
# Layer name: Conv2D - block4b_project_conv,  SI on tarin set: 0.999,  SI on test set: 0.999
# Layer name: Add - block4b_add,  SI on tarin set: 0.995,  SI on test set: 0.999
# Layer name: Conv2D - block4c_expand_conv,  SI on tarin set: 0.978,  SI on test set: 0.982
# Layer name: DepthwiseConv2D - block4c_dwconv,  SI on tarin set: 0.983,  SI on test set: 0.984
# Layer name: Multiply - block4c_se_excite,  SI on tarin set: 0.997,  SI on test set: 0.998
# Layer name: Conv2D - block4c_project_conv,  SI on tarin set: 0.995,  SI on test set: 0.999
# Layer name: Add - block4c_add,  SI on tarin set: 0.993,  SI on test set: 0.999
# Layer name: Conv2D - block5a_expand_conv,  SI on tarin set: 0.983,  SI on test set: 0.997
# Layer name: DepthwiseConv2D - block5a_dwconv,  SI on tarin set: 0.962,  SI on test set: 0.968
# Layer name: Multiply - block5a_se_excite,  SI on tarin set: 1.0,  SI on test set: 1.0
# Layer name: Conv2D - block5a_project_conv,  SI on tarin set: 0.997,  SI on test set: 0.999
# Layer name: Conv2D - block5b_expand_conv,  SI on tarin set: 0.995,  SI on test set: 0.998
# Layer name: DepthwiseConv2D - block5b_dwconv,  SI on tarin set: 0.979,  SI on test set: 0.982
# Layer name: Multiply - block5b_se_excite,  SI on tarin set: 0.998,  SI on test set: 0.998
# Layer name: Conv2D - block5b_project_conv,  SI on tarin set: 1.0,  SI on test set: 1.0
# Layer name: Add - block5b_add,  SI on tarin set: 1.0,  SI on test set: 1.0
# Layer name: Conv2D - block5c_expand_conv,  SI on tarin set: 0.993,  SI on test set: 0.993
# Layer name: DepthwiseConv2D - block5c_dwconv,  SI on tarin set: 0.93,  SI on test set: 0.919
# Layer name: Multiply - block5c_se_excite,  SI on tarin set: 0.987,  SI on test set: 0.987
# Layer name: Conv2D - block5c_project_conv,  SI on tarin set: 0.998,  SI on test set: 1.0
# Layer name: Add - block5c_add,  SI on tarin set: 0.998,  SI on test set: 1.0
# Layer name: Conv2D - block6a_expand_conv,  SI on tarin set: 0.997,  SI on test set: 0.996
# Layer name: DepthwiseConv2D - block6a_dwconv,  SI on tarin set: 0.587,  SI on test set: 0.583
# Layer name: Multiply - block6a_se_excite,  SI on tarin set: 0.927,  SI on test set: 0.937
# Layer name: Conv2D - block6a_project_conv,  SI on tarin set: 0.983,  SI on test set: 0.99
# Layer name: Conv2D - block6b_expand_conv,  SI on tarin set: 0.843,  SI on test set: 0.863
# Layer name: DepthwiseConv2D - block6b_dwconv,  SI on tarin set: 0.721,  SI on test set: 0.707
# Layer name: Multiply - block6b_se_excite,  SI on tarin set: 0.895,  SI on test set: 0.911
# Layer name: Conv2D - block6b_project_conv,  SI on tarin set: 0.979,  SI on test set: 0.982
# Layer name: Add - block6b_add,  SI on tarin set: 0.975,  SI on test set: 0.976
# Layer name: Conv2D - block6c_expand_conv,  SI on tarin set: 0.839,  SI on test set: 0.851
# Layer name: DepthwiseConv2D - block6c_dwconv,  SI on tarin set: 0.533,  SI on test set: 0.522
# Layer name: Multiply - block6c_se_excite,  SI on tarin set: 0.923,  SI on test set: 0.858
# Layer name: Conv2D - block6c_project_conv,  SI on tarin set: 0.982,  SI on test set: 0.973
# Layer name: Add - block6c_add,  SI on tarin set: 0.98,  SI on test set: 0.977
# Layer name: Conv2D - block6d_expand_conv,  SI on tarin set: 0.812,  SI on test set: 0.802
# Layer name: DepthwiseConv2D - block6d_dwconv,  SI on tarin set: 0.497,  SI on test set: 0.497
# Layer name: Multiply - block6d_se_excite,  SI on tarin set: 0.903,  SI on test set: 0.941
# Layer name: Conv2D - block6d_project_conv,  SI on tarin set: 0.97,  SI on test set: 0.977
# Layer name: Add - block6d_add,  SI on tarin set: 0.969,  SI on test set: 0.982
# Layer name: Conv2D - block7a_expand_conv,  SI on tarin set: 0.813,  SI on test set: 0.853
# Layer name: DepthwiseConv2D - block7a_dwconv,  SI on tarin set: 0.591,  SI on test set: 0.577
# Layer name: Multiply - block7a_se_excite,  SI on tarin set: 0.752,  SI on test set: 0.756
# Layer name: Conv2D - block7a_project_conv,  SI on tarin set: 0.632,  SI on test set: 0.623
# Layer name: Conv2D - top_conv,  SI on tarin set: 0.554,  SI on test set: 0.575

# %%
# Plot Separation Index trend
# The SI vlaue is calculated of some layers within convolutional blocks in EfficientNet-B0
plt.figure(num=None, figsize=(17,10), dpi=150)
plt.title("The SI vlaues of some layers within convolutional blocks of EfficientNet-B0 model")

tick_marks = np.arange(len(selected_layers))
plt.xticks(tick_marks,selected_layers,rotation=90)

plt.plot(SI_on_test_set,'bo-')
plt.plot(SI_on_train_set,'ro-')

plt.legend(['Sepration Index on test set','Sepration Index on train set'], loc='lower right')
plt.grid(color='k', linestyle='-', linewidth=2, alpha=0.25)

plt.show()

# %% [markdown]
# ### SI values for the dense layer (last layer of the model)

# %%
# SI values for the dense layer (last layer of the model)

layer_model = tf.keras.Model(model.input, model.layers[-1].output)

predictions = layer_model.predict(sliced_ds_train)
value = calculate_separation_index(predictions, train_set_labels)
SI_dense_on_train_set = value
del predictions

predictions = layer_model.predict(sliced_ds_test)
value = calculate_separation_index(predictions, test_set_labels)
SI_dense_on_test_set = value
del predictions

del layer_model


print(f"SI values for the dense layer, on train set is {round(SI_dense_on_train_set,3)}, also on test set is {round(SI_dense_on_test_set,3)}")
# Out:
# SI values for the dense layer, on train set is 0.138, also on test set is 0.143

# %% [markdown]
# ### Extra plots: Depths and number of parameters of colvolutional layers

# %%
layers_types = []
num_parameters = []
layers_depths = []

for layer in model.layers:
    if isinstance(layer, layers.Conv2D):
        num_parameters.append(layer.count_params())
        layers_depths.append(layer.output_shape[-1])

        layers_types.append(layer.__class__.__name__)

# %%
# Plot increasing trend of the convolutional layers' parameters through EfficientNet-B0
plt.figure(num=None, figsize=(15,6), dpi=150)
tick_marks = np.arange(len(layers_types))
plt.xticks(tick_marks,layers_types,rotation=90)

plt.plot(num_parameters,'ro-')

plt.legend(['Number of parameters of the convolutional layers through the model'])
plt.grid(color='k', linestyle='-', linewidth=2, alpha=0.25)
plt.show()

# %%
# Plot increasing trend of the convolutional layers' depths through EfficientNet-B0
plt.figure(num=None, figsize=(15,6), dpi=150)
tick_marks = np.arange(len(layers_types))
plt.xticks(tick_marks,layers_types,rotation=90)

plt.plot(layers_depths,'bo-')

plt.legend(['Depth of the convolutional layers through the model'])
plt.grid(color='k', linestyle='-', linewidth=2, alpha=0.25)
plt.show()
